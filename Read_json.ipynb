# %%
import json
filepath = '../data/json/0826_1000_LCT_DESKTOP-539136F.json'
f = open(filepath)
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
data['trials'][1]
# Out:
# {'gamble details': {'submitted': True,
#   'submit ts': 757615.2265703,
#   'result roll': None,
#   'choices': [{'time': 757614.5825843, 'side': 'RIGHT', 'choice': 'INVEST'}],
#   'gamble parameters': {'gamble number': 4,
#    'keep amount': 8,
#    'invest amount 1': 2.2,
#    'invest probability 1': 0.32,
#    'invest amount 2': 11.8,
#    'invest probability 2': 0.68,
#    'condition': 'social',
#    'ambiguity': 0,
#    'invest picture': 'CFD-BM-227-191-N.jpg',
#    'invest image': 'GambleImages/4_INVEST__SOCIAL__NOTCLICKED',
#    'keep image': 'GambleImages/4_KEEP__NOTCLICKED'},
#   'left is keep': True},
#  'lct': [{'time': 757613.6608333,
#    'event': {'show screen': 'gamble',
#     'parameters': {'trial number': 2,
#      'left is keep': True,
#      'gamble': {'gamble number': 4,
#       'keep amount': 8,
#       'invest amount 1': 2.2,
#       'invest probability 1': 0.32,
#       'invest amount 2': 11.8,
#       'invest probability 2': 0.68,
# ...

# %%
data['details']
# Out:
# {'id': '0826_1000_LCT_DESKTOP-539136F',
#  'trials played': 132,
#  'gambles presented': {'1_computer': {'trials shown on': [39],
#    'trials skipped on': [],
#    'trial chosen on': 39,
#    'repeats': 0},
#   '1_social': {'trials shown on': [110],
#    'trials skipped on': [],
#    'trial chosen on': 110,
#    'repeats': 0},
#   '2_computer': {'trials shown on': [32],
#    'trials skipped on': [],
#    'trial chosen on': 32,
#    'repeats': 0},
#   '2_social': {'trials shown on': [59],
#    'trials skipped on': [],
#    'trial chosen on': 59,
#    'repeats': 0},
#   '3_computer': {'trials shown on': [28],
#    'trials skipped on': [],
#    'trial chosen on': 28,
#    'repeats': 0},
#   '3_social': {'trials shown on': [52],
#    'trials skipped on': [],
#    'trial chosen on': 52,
#    'repeats': 0},
#   '4_computer': {'trials shown on': [47],
#    'trials skipped on': [],
#    'trial chosen on': 47,
#    'repeats': 0},
#   '4_social': {'trials shown on': [3],
# ...

# %%
data.keys()
# Out:
# dict_keys(['station id', 'file name', 'details', 'trials'])

# %%
len(data['trials'][1])
# Out:
# 4

# %%
len(data['details'])
# Out:
# 11

# %%
data['details']
# Out:
# {'id': '0826_1000_LCT_DESKTOP-539136F',
#  'trials played': 132,
#  'gambles presented': {'1_computer': {'trials shown on': [39],
#    'trials skipped on': [],
#    'trial chosen on': 39,
#    'repeats': 0},
#   '1_social': {'trials shown on': [110],
#    'trials skipped on': [],
#    'trial chosen on': 110,
#    'repeats': 0},
#   '2_computer': {'trials shown on': [32],
#    'trials skipped on': [],
#    'trial chosen on': 32,
#    'repeats': 0},
#   '2_social': {'trials shown on': [59],
#    'trials skipped on': [],
#    'trial chosen on': 59,
#    'repeats': 0},
#   '3_computer': {'trials shown on': [28],
#    'trials skipped on': [],
#    'trial chosen on': 28,
#    'repeats': 0},
#   '3_social': {'trials shown on': [52],
#    'trials skipped on': [],
#    'trial chosen on': 52,
#    'repeats': 0},
#   '4_computer': {'trials shown on': [47],
#    'trials skipped on': [],
#    'trial chosen on': 47,
#    'repeats': 0},
#   '4_social': {'trials shown on': [3],
# ...

# %%
import scipy.io
mat = scipy.io.loadmat('../processed_data/processed/1005_1600_U9TEJGM.mat')

# %%
type(mat)
# Out:
# dict

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'preprocessed_EEG'])

# %%
mat['__header__'], mat['__version__'], mat['__globals__']
# Out:
# (b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Fri Mar 17 23:12:55 2023',
#  '1.0',
#  [])

# %%
mat['preprocessed_EEG'].shape
# Out:
# (21, 218519)

# %%
# removed channel
mat['preprocessed_EEG'][0]
# Out:
# array([-0.20309448, -0.40325695,  0.10120917, ..., -2.0708106 ,
#         0.7455929 ,  1.9313493 ], dtype=float32)

# %%
# time
mat['preprocessed_EEG'][-1][0:100]
# Out:
# array([  0.     ,   3.90625,   7.8125 ,  11.71875,  15.625  ,  19.53125,
#         23.4375 ,  27.34375,  31.25   ,  35.15625,  39.0625 ,  42.96875,
#         46.875  ,  50.78125,  54.6875 ,  58.59375,  62.5    ,  66.40625,
#         70.3125 ,  74.21875,  78.125  ,  82.03125,  85.9375 ,  89.84375,
#         93.75   ,  97.65625, 101.5625 , 105.46875, 109.375  , 113.28125,
#        117.1875 , 121.09375, 125.     , 128.90625, 132.8125 , 136.71875,
#        140.625  , 144.53125, 148.4375 , 152.34375, 156.25   , 160.15625,
#        164.0625 , 167.96875, 171.875  , 175.78125, 179.6875 , 183.59375,
#        187.5    , 191.40625, 195.3125 , 199.21875, 203.125  , 207.03125,
#        210.9375 , 214.84375, 218.75   , 222.65625, 226.5625 , 230.46875,
#        234.375  , 238.28125, 242.1875 , 246.09375, 250.     , 253.90625,
#        257.8125 , 261.71875, 265.625  , 269.53125, 273.4375 , 277.34375,
#        281.25   , 285.15625, 289.0625 , 292.96875, 296.875  , 300.78125,
# ...
